# %%
# %%html
# <style>
#   table {margin-left: 0 !important;}
# </style>
# Out:
# <style>
#   table {margin-left: 0 !important;}
# </style>

# %% [markdown]
# # Projeto Final: Detecção de rostos com uso de máscara de proteção para COVID-19
#
# ## Trabalho em Grupo
# - **Curso:** FGV MBA - Business Analytics e Big Data
# - **Disciplina:** Desafios e Requisitos dos Projetos Analíticos
# - **Professor:** Bruno Brito de Souza
# - **Projeto final:** Detecção de rostos com uso de máscara de proteção
#
# ## Integrantes
# |Github|Kaggle|Nome|Matricula|E-mail|
# |---|---|---|---|---|
# |<a href="https://github.com/DanielFCampos"><img src="https://avatars2.githubusercontent.com/u/31582602?s=460&v=4" title="DanielFCampos" width="40" height="40"></a>|<a href="https://www.kaggle.com/danielferrazcampos"><img src="https://storage.googleapis.com/kaggle-avatars/images/3508055-kg.png" title="DanielFCampos" width="40" height="40"></a>|Daniel Campos|A57635769|[daniel.ferraz.campos@gmail.com](daniel.ferraz.campos@gmail.com)|
# |<a href="https://github.com/ldaniel"><img src="https://avatars2.githubusercontent.com/u/205534?s=460&v=4" title="ldaniel" width="40" height="40"></a>|<a href="https://www.kaggle.com/leandrodaniel"><img src="https://storage.googleapis.com/kaggle-avatars/images/3415144-gr.jpg" title="ldaniel" width="40" height="40"></a>|Leandro Daniel|A57622988|[contato@leandrodaniel.com](contato@leandrodaniel.com)|
# |<a href="https://github.com/ricardobreis"><img src="https://avatars2.githubusercontent.com/u/4885152?s=460&u=470b0bcc829715fd3944d921fec99ad0ea2d6263&v=4" title="ricardobreis" width="40" height="40"></a>|<a href="https://www.kaggle.com/ricardobreis"><img src="https://storage.googleapis.com/kaggle-avatars/images/3201976-kg.jpg" title="ricardobreis" width="40" height="40"></a>|Ricardo Reis|A57590919|[ricardo.l.b.reis@gmail.com](ricardo.l.b.reis@gmail.com)|
# |<a href="https://github.com/RodriGonca"><img src="https://avatars2.githubusercontent.com/u/50252438?s=460&v=4" title="RodriGonca" width="40" height="40"></a>|<a href="https://www.kaggle.com/rodrigonca"><img src="https://storage.googleapis.com/kaggle-avatars/images/3511253-kg.png" title="RodriGonca" width="40" height="40"></a>|Rodrigo Gonçalves|A57566093|[rodrigo.goncalves@me.com](rodrigo.goncalves@me.com)|
# |<a href="https://github.com/ygorlima1"><img src="https://avatars2.githubusercontent.com/u/52429828?s=460&v=4" title="ygorlima1" width="40" height="40"></a>|<a href="https://www.kaggle.com/ygorlima1"><img src="https://storage.googleapis.com/kaggle-avatars/images/3427786-kg.jpg" title="ygorlima1" width="40" height="40"></a>|Ygor Lima|A57549661|[ygor_redesocial@hotmail.com](ygor_redesocial@hotmail.com)|

# %% [markdown]
# ## Libraries Utilizadas para Desenvolvimento da Análise

# %%
import os
import numpy as np
import pandas as pd
import random

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

import cv2 as cv
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, roc_curve, auc, classification_report

from IPython.display import Markdown as md

# %%
seed = 42

random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Data Preparation

# %%
image_size = 256
labels = ['without_mask', 'with_mask']

def get_data(data_dir):
        
    images = []
    
# cria uma lista com o index de cada label com base no nome da raíz do diretório informado.
    for label in labels:
        dir = os.path.join(data_dir, label)
        class_num = labels.index(label)
        
# percorre todas as imagens presentes no diretório, converte para grey_sacale e faz o resizing das imagens.
        for image in os.listdir(dir):    
            image_read = cv.imread(os.path.join(dir,image), cv.IMREAD_GRAYSCALE)
            image_resized = cv.resize(image_read, (image_size, image_size))
            images.append([image_resized, class_num])

    return np.array(images)

load_full_dataset = get_data('/kaggle/input/realworldfacemaskimages/real_world_covid_mask_images/')

# %%
mask_count = np.count_nonzero(load_full_dataset[:,1] == 1)
no_mask_count = np.count_nonzero(load_full_dataset[:,1] == 0)

print('Dataset original\n\n', len(load_full_dataset),
      'imagens no dataset com o tamanho', load_full_dataset[1,0].shape,
      '\n\nProporção',
      '\nSem máscara:\t', no_mask_count,
      '\nCom máscara:\t', mask_count)
# Out:
# Dataset original
#
#  92671 imagens no dataset com o tamanho (256, 256)
#
# Proporção
# Sem máscara:	 90468
# Com máscara:	 2203

# %%
mask_dataset = load_full_dataset[load_full_dataset[:,1]==1]
no_mask_dataset = load_full_dataset[load_full_dataset[:,1]==0]

random_positions = np.random.choice(no_mask_count, replace=False, size=mask_count)

shuffled_no_mask_dataset = no_mask_dataset[random_positions,]

# New loaded set (balanced) with shuffled no-mask dataset
load_full_dataset = np.concatenate((mask_dataset, shuffled_no_mask_dataset))

# %%
mask_count = np.count_nonzero(load_full_dataset[:,1] == 1)
no_mask_count = np.count_nonzero(load_full_dataset[:,1] == 0)

print('Dataset rebalanceado (com seleção aleatória da variável majoritária)\n\n', len(load_full_dataset),
      'imagens no dataset com o tamanho', load_full_dataset[1,0].shape,
      '\n\nProporção',
      '\nSem máscara:\t', no_mask_count,
      '\nCom máscara:\t', mask_count)
# Out:
# Dataset rebalanceado (com seleção aleatória da variável majoritária)
#
#  4406 imagens no dataset com o tamanho (256, 256)
#
# Proporção
# Sem máscara:	 2203
# Com máscara:	 2203

# %%
plt.rcParams.update({'font.size': 16})

fig = plt.figure(figsize = (12, 12))
columns = 4
rows = 3

randomlist = []

for i in range(0, int((columns * rows)/2)):
    n = np.random.randint(0, np.count_nonzero(load_full_dataset[:,1] == 0))
    randomlist.append(n)
    
for i in range(0, int((columns * rows)/2)):
    n = np.random.randint(np.count_nonzero(load_full_dataset[:,1] == 0), len(load_full_dataset))
    randomlist.append(n)
    
for i in range(1, columns * rows + 1):
    rnd = np.random.randint(0, len(load_full_dataset))
    img = load_full_dataset[randomlist[i-1]][0]  
    fig.add_subplot(rows, columns, i)
    plt.title(labels[load_full_dataset[randomlist[i-1]][1]])
    plt.axis('off')
    plt.imshow(img, cmap='gray')

plt.show()

# %%
x_features = []
y_labels = []

for feature, label in load_full_dataset:
    x_features.append(feature)
    y_labels.append(label)
    
del load_full_dataset

# %%
x_features = np.array(x_features).reshape(-1, image_size, image_size, 1)
y_labels = np.array(y_labels)
y_labels = np.expand_dims(y_labels, axis =1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_features, 
                                                    y_labels,
                                                    stratify = y_labels,
                                                    test_size = 0.2, 
                                                    random_state = 2)

del x_features, y_labels

# %%
print('\nTensor de features de treinamento:\t', x_train.shape, 
      '\nImagens:\t', len(x_train), 
      '\nSem máscara:\t', np.count_nonzero(y_train == 0), 
      '\nCom máscara:\t', np.count_nonzero(y_train == 1))

print('\nTensor de labels de treinamento:\t', y_train.shape, 
      '\nQuantidade:\t', len(y_train),
      '\nSem máscara:\t', np.count_nonzero(y_train == 0), 
      '\nCom máscara:\t', np.count_nonzero(y_train == 1))

print('\nTensor de features de teste:\t\t', x_test.shape, 
      '\nImagens:\t', len(x_test),
      '\nSem máscara:\t', np.count_nonzero(y_test == 0), 
      '\nCom máscara:\t', np.count_nonzero(y_test == 1))

print('\nTensor de labels de teste:\t\t', y_test.shape, 
      '\nQuantidade:\t', len(y_test),
      '\nSem máscara:\t', np.count_nonzero(y_test == 0), 
      '\nCom máscara:\t', np.count_nonzero(y_test == 1))
# Out:
# Tensor de features de treinamento:	 (3524, 256, 256, 1)
# Imagens:	 3524
# Sem máscara:	 1762
# Com máscara:	 1762
#
# Tensor de labels de treinamento:	 (3524, 1)
# Quantidade:	 3524
# Sem máscara:	 1762
# Com máscara:	 1762
#
# Tensor de features de teste:		 (882, 256, 256, 1)
# Imagens:	 882
# Sem máscara:	 441
# Com máscara:	 441
#
# Tensor de labels de teste:		 (882, 1)
# Quantidade:	 882
# Sem máscara:	 441
# Com máscara:	 441

# %%
x_train = x_train / 255
x_test  = x_test  / 255

# %% [markdown]
# ## Definição da Arquitetura da Rede Neural

# %%
i = Input(x_train.shape[1:])

a = Flatten()(i)

a = Dense(512, activation = 'relu')(a)
a = Dropout(0.4)(a)

a = Dense(512, activation = 'relu')(a)
a = Dropout(0.3)(a)

a = Dense(512, activation = 'relu')(a)
a = Dropout(0.1)(a)

a = Dense(1, activation = 'sigmoid')(a)

model_NN = Model(i,a)

# %%
i = Input(x_train.shape[1:])

b = Conv2D(32, (3,3), activation ='relu', padding = 'same')(i)
b = BatchNormalization()(b)
b = Conv2D(32, (3,3), activation ='relu', padding = 'same')(b)
b = BatchNormalization()(b)
b = MaxPooling2D(2,2)(b)

b = Conv2D(64, (3,3), activation ='relu', padding = 'same')(b)
b = BatchNormalization()(b)
b = Conv2D(64, (3,3), activation ='relu', padding = 'same')(b)
b = BatchNormalization()(b)
b = MaxPooling2D(2,2)(b)

b = Conv2D(128, (3,3), activation ='relu', padding = 'same')(b)
b = BatchNormalization()(b)
b = Conv2D(128, (3,3), activation ='relu', padding = 'same')(b)
b = BatchNormalization()(b)
b = MaxPooling2D(2,2)(b)

b = Conv2D(256, (3,3), activation ='relu', padding = 'same')(b)
b = BatchNormalization()(b)
b = Conv2D(256, (3,3), activation ='relu', padding = 'same')(b)
b = BatchNormalization()(b)
b = MaxPooling2D(2,2)(b)

b = Flatten()(b)

b = Dense(512, activation = 'relu')(b)
b = Dropout(0.4)(b)

b = Dense(512, activation = 'relu')(b)
b = Dropout(0.3)(b)

b = Dense(512, activation = 'relu')(b)
b = Dropout(0.1)(b)

b = Dense(1, activation = 'sigmoid')(b)

model_CNN = Model(i, b)

# %% [markdown]
# ## Compilando e Visualizando a Arquitetura dos Modelos
# ### Rede Neural Simples

# %%
model_NN.compile(optimizer = 'SGD',
              loss = "binary_crossentropy",
              metrics = ["accuracy"])

model_NN.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 1)]     0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               33554944
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 34,080,769
# Trainable params: 34,080,769
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Rede Neural com Convoluções

# %%
model_CNN.compile(optimizer = 'SGD',
              loss = "binary_crossentropy",
              metrics = ["accuracy"])

model_CNN.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 256, 256, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 256, 256, 32)      320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256, 256, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 32)      9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256, 256, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 256)       295168
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 65536)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               33554944
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 35,256,289
# Trainable params: 35,254,369
# Non-trainable params: 1,920
# _________________________________________________________________

# %% [markdown]
# ## Data Augmentation

# %%
batch_size = 32

train_gen = ImageDataGenerator(rotation_range = 10,
                               horizontal_flip = True,
                               width_shift_range = 0.1,
                               height_shift_range = 0.1,
                               rescale = 1.,
                               zoom_range = 0.2,
                               fill_mode = 'nearest',
                               cval = 0)

train_generator_NN = train_gen.flow(x_train, y_train, batch_size)
train_generator_CNN = train_gen.flow(x_train, y_train, batch_size)

steps_per_epoch = x_train.shape[0] // batch_size

checkpoint_NN = ModelCheckpoint('model_NN.h5', 
                                monitor = 'val_loss', 
                                verbose = 0, 
                                save_best_only = True, 
                                mode = 'auto')

checkpoint_CNN = ModelCheckpoint('model_CNN.h5', 
                                 monitor = 'val_loss', 
                                 verbose = 0, 
                                 save_best_only = True, 
                                 mode = 'auto')

# %% [markdown]
# ## Treinamento dos Modelos

# %%
epochs = 100

history_NN = model_NN.fit(train_generator_NN, 
                          validation_data = (x_test, y_test), 
                          steps_per_epoch = steps_per_epoch, 
                          epochs = epochs,
                          callbacks = [checkpoint_NN],
                          verbose = 2)

history_CNN = model_CNN.fit(train_generator_CNN, 
                            validation_data = (x_test, y_test), 
                            steps_per_epoch = steps_per_epoch, 
                            epochs = epochs,
                            callbacks = [checkpoint_CNN],
                            verbose = 2)
# Out:
# Train for 110 steps, validate on 882 samples
# Epoch 1/100
# 110/110 - 18s - loss: 0.7106 - accuracy: 0.5676 - val_loss: 0.6143 - val_accuracy: 0.5771
# Epoch 2/100
# 110/110 - 17s - loss: 0.6005 - accuracy: 0.6615 - val_loss: 0.5133 - val_accuracy: 0.7415
# Epoch 3/100
# 110/110 - 17s - loss: 0.5450 - accuracy: 0.7030 - val_loss: 0.4371 - val_accuracy: 0.8027
# Epoch 4/100
# 110/110 - 18s - loss: 0.5220 - accuracy: 0.7294 - val_loss: 0.4281 - val_accuracy: 0.7710
# Epoch 5/100
# 110/110 - 16s - loss: 0.4895 - accuracy: 0.7543 - val_loss: 0.4227 - val_accuracy: 0.8084
# Epoch 6/100
# 110/110 - 17s - loss: 0.4637 - accuracy: 0.7666 - val_loss: 0.3493 - val_accuracy: 0.8560
# Epoch 7/100
# 110/110 - 18s - loss: 0.4641 - accuracy: 0.7583 - val_loss: 0.3509 - val_accuracy: 0.8345
# Epoch 8/100
# 110/110 - 17s - loss: 0.4534 - accuracy: 0.7784 - val_loss: 0.3632 - val_accuracy: 0.8186
# Epoch 9/100
# 110/110 - 17s - loss: 0.4458 - accuracy: 0.7867 - val_loss: 0.3505 - val_accuracy: 0.8277
# Epoch 10/100
# 110/110 - 17s - loss: 0.4219 - accuracy: 0.7961 - val_loss: 0.3430 - val_accuracy: 0.8333
# Epoch 11/100
# 110/110 - 18s - loss: 0.4243 - accuracy: 0.8021 - val_loss: 0.3331 - val_accuracy: 0.8413
# Epoch 12/100
# 110/110 - 17s - loss: 0.4283 - accuracy: 0.8010 - val_loss: 0.3243 - val_accuracy: 0.8662
# Epoch 13/100
# 110/110 - 17s - loss: 0.4082 - accuracy: 0.8084 - val_loss: 0.3203 - val_accuracy: 0.8821
# Epoch 14/100
# 110/110 - 17s - loss: 0.4131 - accuracy: 0.8119 - val_loss: 0.3869 - val_accuracy: 0.8254
# Epoch 15/100
# 110/110 - 17s - loss: 0.4039 - accuracy: 0.8081 - val_loss: 0.3197 - val_accuracy: 0.8628
# Epoch 16/100
# 110/110 - 16s - loss: 0.4140 - accuracy: 0.8116 - val_loss: 0.3516 - val_accuracy: 0.8390
# Epoch 17/100
# 110/110 - 18s - loss: 0.4047 - accuracy: 0.8101 - val_loss: 0.3020 - val_accuracy: 0.8673
# Epoch 18/100
# 110/110 - 18s - loss: 0.3938 - accuracy: 0.8139 - val_loss: 0.3011 - val_accuracy: 0.8912
# Epoch 19/100
# 110/110 - 17s - loss: 0.3900 - accuracy: 0.8222 - val_loss: 0.2884 - val_accuracy: 0.8934
# Epoch 20/100
# 110/110 - 17s - loss: 0.3758 - accuracy: 0.8356 - val_loss: 0.2857 - val_accuracy: 0.8844
# Epoch 21/100
# 110/110 - 18s - loss: 0.3792 - accuracy: 0.8247 - val_loss: 0.3150 - val_accuracy: 0.8889
# Epoch 22/100
# 110/110 - 17s - loss: 0.3829 - accuracy: 0.8296 - val_loss: 0.2886 - val_accuracy: 0.9036
# Epoch 23/100
# 110/110 - 16s - loss: 0.3843 - accuracy: 0.8216 - val_loss: 0.2915 - val_accuracy: 0.9025
# Epoch 24/100
# 110/110 - 17s - loss: 0.3844 - accuracy: 0.8325 - val_loss: 0.3184 - val_accuracy: 0.8560
# Epoch 25/100
# 110/110 - 17s - loss: 0.3680 - accuracy: 0.8348 - val_loss: 0.2754 - val_accuracy: 0.9014
# Epoch 26/100
# 110/110 - 17s - loss: 0.3678 - accuracy: 0.8336 - val_loss: 0.3079 - val_accuracy: 0.8753
# Epoch 27/100
# 110/110 - 16s - loss: 0.3598 - accuracy: 0.8356 - val_loss: 0.2917 - val_accuracy: 0.8741
# Epoch 28/100
# 110/110 - 18s - loss: 0.3563 - accuracy: 0.8431 - val_loss: 0.3118 - val_accuracy: 0.8583
# Epoch 29/100
# 110/110 - 17s - loss: 0.3583 - accuracy: 0.8494 - val_loss: 0.2666 - val_accuracy: 0.8957
# Epoch 30/100
# 110/110 - 17s - loss: 0.3618 - accuracy: 0.8356 - val_loss: 0.3144 - val_accuracy: 0.8878
# Epoch 31/100
# 110/110 - 17s - loss: 0.3536 - accuracy: 0.8379 - val_loss: 0.2997 - val_accuracy: 0.8934
# Epoch 32/100
# 110/110 - 17s - loss: 0.3682 - accuracy: 0.8425 - val_loss: 0.2860 - val_accuracy: 0.9014
# Epoch 33/100
# 110/110 - 17s - loss: 0.3433 - accuracy: 0.8554 - val_loss: 0.3032 - val_accuracy: 0.8946
# Epoch 34/100
# 110/110 - 16s - loss: 0.3584 - accuracy: 0.8422 - val_loss: 0.3054 - val_accuracy: 0.8719
# Epoch 35/100
# 110/110 - 18s - loss: 0.3580 - accuracy: 0.8385 - val_loss: 0.2749 - val_accuracy: 0.8946
# Epoch 36/100
# 110/110 - 17s - loss: 0.3576 - accuracy: 0.8379 - val_loss: 0.3241 - val_accuracy: 0.8435
# Epoch 37/100
# 110/110 - 17s - loss: 0.3468 - accuracy: 0.8497 - val_loss: 0.2709 - val_accuracy: 0.8900
# Epoch 38/100
# 110/110 - 17s - loss: 0.3454 - accuracy: 0.8528 - val_loss: 0.3080 - val_accuracy: 0.8549
# Epoch 39/100
# 110/110 - 18s - loss: 0.3486 - accuracy: 0.8459 - val_loss: 0.2744 - val_accuracy: 0.9002
# Epoch 40/100
# 110/110 - 17s - loss: 0.3468 - accuracy: 0.8465 - val_loss: 0.2783 - val_accuracy: 0.9048
# Epoch 41/100
# 110/110 - 17s - loss: 0.3456 - accuracy: 0.8451 - val_loss: 0.2873 - val_accuracy: 0.8968
# Epoch 42/100
# 110/110 - 18s - loss: 0.3437 - accuracy: 0.8522 - val_loss: 0.2831 - val_accuracy: 0.8855
# Epoch 43/100
# 110/110 - 17s - loss: 0.3351 - accuracy: 0.8528 - val_loss: 0.2795 - val_accuracy: 0.8991
# Epoch 44/100
# 110/110 - 17s - loss: 0.3316 - accuracy: 0.8514 - val_loss: 0.2751 - val_accuracy: 0.9082
# Epoch 45/100
# 110/110 - 17s - loss: 0.3383 - accuracy: 0.8474 - val_loss: 0.3170 - val_accuracy: 0.8605
# Epoch 46/100
# 110/110 - 18s - loss: 0.3299 - accuracy: 0.8525 - val_loss: 0.2970 - val_accuracy: 0.8741
# Epoch 47/100
# 110/110 - 17s - loss: 0.3395 - accuracy: 0.8574 - val_loss: 0.2733 - val_accuracy: 0.8900
# Epoch 48/100
# 110/110 - 17s - loss: 0.3381 - accuracy: 0.8508 - val_loss: 0.3001 - val_accuracy: 0.8685
# Epoch 49/100
# 110/110 - 18s - loss: 0.3417 - accuracy: 0.8528 - val_loss: 0.2915 - val_accuracy: 0.8900
# Epoch 50/100
# 110/110 - 17s - loss: 0.3384 - accuracy: 0.8517 - val_loss: 0.3042 - val_accuracy: 0.8651
# Epoch 51/100
# 110/110 - 17s - loss: 0.3430 - accuracy: 0.8465 - val_loss: 0.2815 - val_accuracy: 0.8991
# Epoch 52/100
# 110/110 - 17s - loss: 0.3290 - accuracy: 0.8585 - val_loss: 0.2977 - val_accuracy: 0.8798
# Epoch 53/100
# 110/110 - 18s - loss: 0.3221 - accuracy: 0.8565 - val_loss: 0.2783 - val_accuracy: 0.9059
# Epoch 54/100
# 110/110 - 17s - loss: 0.3345 - accuracy: 0.8505 - val_loss: 0.2854 - val_accuracy: 0.8889
# Epoch 55/100
# 110/110 - 17s - loss: 0.3265 - accuracy: 0.8577 - val_loss: 0.2925 - val_accuracy: 0.8821
# Epoch 56/100
# 110/110 - 17s - loss: 0.3364 - accuracy: 0.8548 - val_loss: 0.2672 - val_accuracy: 0.9070
# Epoch 57/100
# 110/110 - 17s - loss: 0.3241 - accuracy: 0.8625 - val_loss: 0.3009 - val_accuracy: 0.8594
# Epoch 58/100
# 110/110 - 17s - loss: 0.3180 - accuracy: 0.8625 - val_loss: 0.2603 - val_accuracy: 0.9070
# Epoch 59/100
# 110/110 - 17s - loss: 0.3213 - accuracy: 0.8654 - val_loss: 0.2799 - val_accuracy: 0.8968
# Epoch 60/100
# 110/110 - 18s - loss: 0.3214 - accuracy: 0.8654 - val_loss: 0.2979 - val_accuracy: 0.8844
# Epoch 61/100
# 110/110 - 17s - loss: 0.3244 - accuracy: 0.8557 - val_loss: 0.2764 - val_accuracy: 0.9014
# Epoch 62/100
# 110/110 - 17s - loss: 0.3273 - accuracy: 0.8577 - val_loss: 0.2856 - val_accuracy: 0.8957
# Epoch 63/100
# 110/110 - 18s - loss: 0.3095 - accuracy: 0.8688 - val_loss: 0.3006 - val_accuracy: 0.8968
# Epoch 64/100
# 110/110 - 17s - loss: 0.3219 - accuracy: 0.8643 - val_loss: 0.2821 - val_accuracy: 0.8980
# Epoch 65/100
# 110/110 - 17s - loss: 0.3226 - accuracy: 0.8603 - val_loss: 0.2890 - val_accuracy: 0.8821
# Epoch 66/100
# 110/110 - 17s - loss: 0.3149 - accuracy: 0.8660 - val_loss: 0.2670 - val_accuracy: 0.9002
# Epoch 67/100
# 110/110 - 18s - loss: 0.3245 - accuracy: 0.8640 - val_loss: 0.3460 - val_accuracy: 0.8413
# Epoch 68/100
# 110/110 - 17s - loss: 0.3274 - accuracy: 0.8600 - val_loss: 0.2622 - val_accuracy: 0.9025
# Epoch 69/100
# 110/110 - 17s - loss: 0.3216 - accuracy: 0.8643 - val_loss: 0.3086 - val_accuracy: 0.8594
# Epoch 70/100
# 110/110 - 18s - loss: 0.3238 - accuracy: 0.8651 - val_loss: 0.3022 - val_accuracy: 0.8730
# Epoch 71/100
# 110/110 - 17s - loss: 0.3191 - accuracy: 0.8560 - val_loss: 0.2759 - val_accuracy: 0.8855
# Epoch 72/100
# 110/110 - 17s - loss: 0.3276 - accuracy: 0.8562 - val_loss: 0.2829 - val_accuracy: 0.9002
# Epoch 73/100
# 110/110 - 17s - loss: 0.3216 - accuracy: 0.8605 - val_loss: 0.2670 - val_accuracy: 0.8991
# Epoch 74/100
# 110/110 - 18s - loss: 0.3225 - accuracy: 0.8585 - val_loss: 0.2858 - val_accuracy: 0.8855
# Epoch 75/100
# 110/110 - 17s - loss: 0.3140 - accuracy: 0.8654 - val_loss: 0.2901 - val_accuracy: 0.8832
# Epoch 76/100
# 110/110 - 17s - loss: 0.3211 - accuracy: 0.8588 - val_loss: 0.3004 - val_accuracy: 0.8662
# Epoch 77/100
# 110/110 - 18s - loss: 0.3273 - accuracy: 0.8591 - val_loss: 0.2906 - val_accuracy: 0.8764
# Epoch 78/100
# 110/110 - 17s - loss: 0.3307 - accuracy: 0.8545 - val_loss: 0.2749 - val_accuracy: 0.9025
# Epoch 79/100
# 110/110 - 17s - loss: 0.3176 - accuracy: 0.8720 - val_loss: 0.2805 - val_accuracy: 0.8934
# Epoch 80/100
# 110/110 - 17s - loss: 0.3114 - accuracy: 0.8677 - val_loss: 0.2663 - val_accuracy: 0.9036
# Epoch 81/100
# 110/110 - 18s - loss: 0.3000 - accuracy: 0.8780 - val_loss: 0.2779 - val_accuracy: 0.9025
# Epoch 82/100
# 110/110 - 17s - loss: 0.3057 - accuracy: 0.8729 - val_loss: 0.2877 - val_accuracy: 0.8741
# Epoch 83/100
# 110/110 - 17s - loss: 0.3018 - accuracy: 0.8708 - val_loss: 0.2823 - val_accuracy: 0.8787
# Epoch 84/100
# 110/110 - 18s - loss: 0.3065 - accuracy: 0.8668 - val_loss: 0.2707 - val_accuracy: 0.9070
# Epoch 85/100
# 110/110 - 17s - loss: 0.3082 - accuracy: 0.8611 - val_loss: 0.3178 - val_accuracy: 0.8560
# Epoch 86/100
# 110/110 - 17s - loss: 0.2957 - accuracy: 0.8756 - val_loss: 0.2813 - val_accuracy: 0.8866
# Epoch 87/100
# 110/110 - 17s - loss: 0.3111 - accuracy: 0.8660 - val_loss: 0.2961 - val_accuracy: 0.8696
# Epoch 88/100
# 110/110 - 18s - loss: 0.3103 - accuracy: 0.8668 - val_loss: 0.3006 - val_accuracy: 0.8662
# Epoch 89/100
# 110/110 - 17s - loss: 0.3184 - accuracy: 0.8588 - val_loss: 0.2918 - val_accuracy: 0.8741
# Epoch 90/100
# 110/110 - 17s - loss: 0.3031 - accuracy: 0.8749 - val_loss: 0.2808 - val_accuracy: 0.8946
# Epoch 91/100
# 110/110 - 18s - loss: 0.3158 - accuracy: 0.8574 - val_loss: 0.2722 - val_accuracy: 0.9014
# Epoch 92/100
# 110/110 - 17s - loss: 0.2915 - accuracy: 0.8746 - val_loss: 0.2959 - val_accuracy: 0.8707
# Epoch 93/100
# 110/110 - 16s - loss: 0.3021 - accuracy: 0.8666 - val_loss: 0.3158 - val_accuracy: 0.8458
# Epoch 94/100
# 110/110 - 17s - loss: 0.3131 - accuracy: 0.8671 - val_loss: 0.2838 - val_accuracy: 0.8764
# Epoch 95/100
# 110/110 - 18s - loss: 0.3141 - accuracy: 0.8643 - val_loss: 0.2713 - val_accuracy: 0.8934
# Epoch 96/100
# 110/110 - 17s - loss: 0.3055 - accuracy: 0.8708 - val_loss: 0.2848 - val_accuracy: 0.8912
# Epoch 97/100
# 110/110 - 17s - loss: 0.3023 - accuracy: 0.8694 - val_loss: 0.2902 - val_accuracy: 0.8776
# Epoch 98/100
# 110/110 - 18s - loss: 0.3022 - accuracy: 0.8711 - val_loss: 0.2964 - val_accuracy: 0.8730
# Epoch 99/100
# 110/110 - 17s - loss: 0.3033 - accuracy: 0.8751 - val_loss: 0.2868 - val_accuracy: 0.8764
# Epoch 100/100
# 110/110 - 16s - loss: 0.3027 - accuracy: 0.8688 - val_loss: 0.2714 - val_accuracy: 0.9002
# Train for 110 steps, validate on 882 samples
# Epoch 1/100
# 110/110 - 31s - loss: 0.4357 - accuracy: 0.8245 - val_loss: 1.0593 - val_accuracy: 0.5000
# Epoch 2/100
# 110/110 - 23s - loss: 0.2202 - accuracy: 0.9132 - val_loss: 1.3719 - val_accuracy: 0.5000
# Epoch 3/100
# 110/110 - 24s - loss: 0.1676 - accuracy: 0.9356 - val_loss: 1.0359 - val_accuracy: 0.5238
# Epoch 4/100
# 110/110 - 25s - loss: 0.1358 - accuracy: 0.9487 - val_loss: 0.5930 - val_accuracy: 0.6939
# Epoch 5/100
# 110/110 - 24s - loss: 0.1193 - accuracy: 0.9553 - val_loss: 0.5343 - val_accuracy: 0.7880
# Epoch 6/100
# 110/110 - 25s - loss: 0.1125 - accuracy: 0.9570 - val_loss: 0.2271 - val_accuracy: 0.8968
# Epoch 7/100
# 110/110 - 23s - loss: 0.0968 - accuracy: 0.9653 - val_loss: 0.2305 - val_accuracy: 0.9240
# Epoch 8/100
# 110/110 - 24s - loss: 0.0920 - accuracy: 0.9671 - val_loss: 0.1104 - val_accuracy: 0.9603
# Epoch 9/100
# 110/110 - 25s - loss: 0.0736 - accuracy: 0.9728 - val_loss: 0.0811 - val_accuracy: 0.9717
# Epoch 10/100
# 110/110 - 23s - loss: 0.0794 - accuracy: 0.9694 - val_loss: 1.8349 - val_accuracy: 0.7098
# Epoch 11/100
# 110/110 - 24s - loss: 0.0581 - accuracy: 0.9785 - val_loss: 0.1500 - val_accuracy: 0.9546
# Epoch 12/100
# 110/110 - 23s - loss: 0.0636 - accuracy: 0.9779 - val_loss: 0.1040 - val_accuracy: 0.9671
# Epoch 13/100
# 110/110 - 23s - loss: 0.0556 - accuracy: 0.9825 - val_loss: 0.1003 - val_accuracy: 0.9671
# Epoch 14/100
# 110/110 - 24s - loss: 0.0447 - accuracy: 0.9851 - val_loss: 0.1378 - val_accuracy: 0.9580
# Epoch 15/100
# 110/110 - 23s - loss: 0.0540 - accuracy: 0.9791 - val_loss: 0.0862 - val_accuracy: 0.9728
# Epoch 16/100
# 110/110 - 25s - loss: 0.0466 - accuracy: 0.9822 - val_loss: 0.0635 - val_accuracy: 0.9773
# Epoch 17/100
# 110/110 - 24s - loss: 0.0336 - accuracy: 0.9888 - val_loss: 0.0589 - val_accuracy: 0.9773
# Epoch 18/100
# 110/110 - 24s - loss: 0.0424 - accuracy: 0.9842 - val_loss: 0.1903 - val_accuracy: 0.9524
# Epoch 19/100
# 110/110 - 24s - loss: 0.0401 - accuracy: 0.9854 - val_loss: 0.1004 - val_accuracy: 0.9649
# Epoch 20/100
# 110/110 - 23s - loss: 0.0440 - accuracy: 0.9834 - val_loss: 0.0665 - val_accuracy: 0.9751
# Epoch 21/100
# 110/110 - 24s - loss: 0.0376 - accuracy: 0.9857 - val_loss: 0.0910 - val_accuracy: 0.9739
# Epoch 22/100
# 110/110 - 24s - loss: 0.0309 - accuracy: 0.9908 - val_loss: 0.0561 - val_accuracy: 0.9841
# Epoch 23/100
# 110/110 - 23s - loss: 0.0307 - accuracy: 0.9888 - val_loss: 1.1909 - val_accuracy: 0.8129
# Epoch 24/100
# 110/110 - 25s - loss: 0.0350 - accuracy: 0.9880 - val_loss: 0.0277 - val_accuracy: 0.9909
# Epoch 25/100
# 110/110 - 23s - loss: 0.0260 - accuracy: 0.9917 - val_loss: 0.0232 - val_accuracy: 0.9909
# Epoch 26/100
# 110/110 - 24s - loss: 0.0287 - accuracy: 0.9888 - val_loss: 0.0565 - val_accuracy: 0.9830
# Epoch 27/100
# 110/110 - 23s - loss: 0.0281 - accuracy: 0.9883 - val_loss: 0.0568 - val_accuracy: 0.9785
# Epoch 28/100
# 110/110 - 23s - loss: 0.0248 - accuracy: 0.9908 - val_loss: 0.0308 - val_accuracy: 0.9864
# Epoch 29/100
# 110/110 - 24s - loss: 0.0268 - accuracy: 0.9903 - val_loss: 0.1967 - val_accuracy: 0.9546
# Epoch 30/100
# 110/110 - 23s - loss: 0.0240 - accuracy: 0.9923 - val_loss: 0.1134 - val_accuracy: 0.9671
# Epoch 31/100
# 110/110 - 24s - loss: 0.0181 - accuracy: 0.9940 - val_loss: 0.1955 - val_accuracy: 0.9512
# Epoch 32/100
# 110/110 - 23s - loss: 0.0196 - accuracy: 0.9940 - val_loss: 0.1009 - val_accuracy: 0.9705
# Epoch 33/100
# 110/110 - 23s - loss: 0.0217 - accuracy: 0.9920 - val_loss: 0.0389 - val_accuracy: 0.9864
# Epoch 34/100
# 110/110 - 24s - loss: 0.0231 - accuracy: 0.9914 - val_loss: 0.0436 - val_accuracy: 0.9853
# Epoch 35/100
# 110/110 - 23s - loss: 0.0128 - accuracy: 0.9946 - val_loss: 0.0488 - val_accuracy: 0.9853
# Epoch 36/100
# 110/110 - 24s - loss: 0.0189 - accuracy: 0.9928 - val_loss: 0.0374 - val_accuracy: 0.9898
# Epoch 37/100
# 110/110 - 23s - loss: 0.0172 - accuracy: 0.9940 - val_loss: 0.2338 - val_accuracy: 0.9558
# Epoch 38/100
# 110/110 - 23s - loss: 0.0167 - accuracy: 0.9937 - val_loss: 0.1578 - val_accuracy: 0.9546
# Epoch 39/100
# 110/110 - 24s - loss: 0.0161 - accuracy: 0.9951 - val_loss: 0.1618 - val_accuracy: 0.9535
# Epoch 40/100
# 110/110 - 24s - loss: 0.0287 - accuracy: 0.9934 - val_loss: 0.0217 - val_accuracy: 0.9943
# Epoch 41/100
# 110/110 - 24s - loss: 0.0176 - accuracy: 0.9946 - val_loss: 0.0274 - val_accuracy: 0.9921
# Epoch 42/100
# 110/110 - 24s - loss: 0.0139 - accuracy: 0.9946 - val_loss: 0.0826 - val_accuracy: 0.9762
# Epoch 43/100
# 110/110 - 24s - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.0202 - val_accuracy: 0.9955
# Epoch 44/100
# 110/110 - 24s - loss: 0.0130 - accuracy: 0.9963 - val_loss: 0.0278 - val_accuracy: 0.9909
# Epoch 45/100
# 110/110 - 23s - loss: 0.0136 - accuracy: 0.9951 - val_loss: 0.0704 - val_accuracy: 0.9785
# Epoch 46/100
# 110/110 - 23s - loss: 0.0147 - accuracy: 0.9940 - val_loss: 0.0332 - val_accuracy: 0.9921
# Epoch 47/100
# 110/110 - 24s - loss: 0.0199 - accuracy: 0.9926 - val_loss: 0.1201 - val_accuracy: 0.9728
# Epoch 48/100
# 110/110 - 24s - loss: 0.0168 - accuracy: 0.9940 - val_loss: 0.0607 - val_accuracy: 0.9864
# Epoch 49/100
# 110/110 - 24s - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.0318 - val_accuracy: 0.9887
# Epoch 50/100
# 110/110 - 23s - loss: 0.0147 - accuracy: 0.9946 - val_loss: 0.1080 - val_accuracy: 0.9739
# Epoch 51/100
# 110/110 - 23s - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.0314 - val_accuracy: 0.9909
# Epoch 52/100
# 110/110 - 24s - loss: 0.0145 - accuracy: 0.9948 - val_loss: 0.0476 - val_accuracy: 0.9864
# Epoch 53/100
# 110/110 - 23s - loss: 0.0100 - accuracy: 0.9960 - val_loss: 0.0437 - val_accuracy: 0.9830
# Epoch 54/100
# 110/110 - 24s - loss: 0.0149 - accuracy: 0.9948 - val_loss: 0.0280 - val_accuracy: 0.9898
# Epoch 55/100
# 110/110 - 23s - loss: 0.0116 - accuracy: 0.9960 - val_loss: 0.0355 - val_accuracy: 0.9853
# Epoch 56/100
# 110/110 - 23s - loss: 0.0085 - accuracy: 0.9960 - val_loss: 0.0433 - val_accuracy: 0.9853
# Epoch 57/100
# 110/110 - 24s - loss: 0.0078 - accuracy: 0.9966 - val_loss: 0.0531 - val_accuracy: 0.9819
# Epoch 58/100
# 110/110 - 23s - loss: 0.0143 - accuracy: 0.9946 - val_loss: 0.0495 - val_accuracy: 0.9841
# Epoch 59/100
# 110/110 - 24s - loss: 0.0125 - accuracy: 0.9948 - val_loss: 0.0428 - val_accuracy: 0.9841
# Epoch 60/100
# 110/110 - 23s - loss: 0.0105 - accuracy: 0.9963 - val_loss: 0.0851 - val_accuracy: 0.9739
# Epoch 61/100
# 110/110 - 23s - loss: 0.0100 - accuracy: 0.9957 - val_loss: 0.1175 - val_accuracy: 0.9717
# Epoch 62/100
# 110/110 - 24s - loss: 0.0146 - accuracy: 0.9931 - val_loss: 0.0324 - val_accuracy: 0.9909
# Epoch 63/100
# 110/110 - 24s - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0188 - val_accuracy: 0.9966
# Epoch 64/100
# 110/110 - 24s - loss: 0.0105 - accuracy: 0.9951 - val_loss: 0.0537 - val_accuracy: 0.9819
# Epoch 65/100
# 110/110 - 23s - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0378 - val_accuracy: 0.9921
# Epoch 66/100
# 110/110 - 23s - loss: 0.0053 - accuracy: 0.9980 - val_loss: 0.0289 - val_accuracy: 0.9932
# Epoch 67/100
# 110/110 - 24s - loss: 0.0073 - accuracy: 0.9989 - val_loss: 0.0492 - val_accuracy: 0.9875
# Epoch 68/100
# 110/110 - 23s - loss: 0.0107 - accuracy: 0.9968 - val_loss: 0.0222 - val_accuracy: 0.9955
# Epoch 69/100
# 110/110 - 24s - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.2062 - val_accuracy: 0.9637
# Epoch 70/100
# 110/110 - 24s - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0574 - val_accuracy: 0.9853
# Epoch 71/100
# 110/110 - 23s - loss: 0.0065 - accuracy: 0.9971 - val_loss: 0.0229 - val_accuracy: 0.9921
# Epoch 72/100
# 110/110 - 24s - loss: 0.0099 - accuracy: 0.9963 - val_loss: 0.0474 - val_accuracy: 0.9909
# Epoch 73/100
# 110/110 - 23s - loss: 0.0089 - accuracy: 0.9980 - val_loss: 0.1094 - val_accuracy: 0.9785
# Epoch 74/100
# 110/110 - 23s - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.0841 - val_accuracy: 0.9785
# Epoch 75/100
# 110/110 - 24s - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.0187 - val_accuracy: 0.9955
# Epoch 76/100
# 110/110 - 23s - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0283 - val_accuracy: 0.9943
# Epoch 77/100
# 110/110 - 25s - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.0182 - val_accuracy: 0.9932
# Epoch 78/100
# 110/110 - 23s - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0188 - val_accuracy: 0.9943
# Epoch 79/100
# 110/110 - 23s - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.0211 - val_accuracy: 0.9966
# Epoch 80/100
# 110/110 - 24s - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0420 - val_accuracy: 0.9898
# Epoch 81/100
# 110/110 - 23s - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.2690 - val_accuracy: 0.9535
# Epoch 82/100
# 110/110 - 24s - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0315 - val_accuracy: 0.9932
# Epoch 83/100
# 110/110 - 23s - loss: 0.0077 - accuracy: 0.9963 - val_loss: 0.0306 - val_accuracy: 0.9932
# Epoch 84/100
# 110/110 - 24s - loss: 0.0129 - accuracy: 0.9954 - val_loss: 0.0182 - val_accuracy: 0.9966
# Epoch 85/100
# 110/110 - 24s - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.0220 - val_accuracy: 0.9921
# Epoch 86/100
# 110/110 - 24s - loss: 0.0052 - accuracy: 0.9974 - val_loss: 0.0168 - val_accuracy: 0.9955
# Epoch 87/100
# 110/110 - 24s - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0170 - val_accuracy: 0.9966
# Epoch 88/100
# 110/110 - 23s - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.2118 - val_accuracy: 0.9569
# Epoch 89/100
# 110/110 - 23s - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0628 - val_accuracy: 0.9875
# Epoch 90/100
# 110/110 - 24s - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.0232 - val_accuracy: 0.9932
# Epoch 91/100
# 110/110 - 23s - loss: 0.0074 - accuracy: 0.9971 - val_loss: 0.0155 - val_accuracy: 0.9966
# Epoch 92/100
# 110/110 - 24s - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0367 - val_accuracy: 0.9943
# Epoch 93/100
# 110/110 - 23s - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0456 - val_accuracy: 0.9887
# Epoch 94/100
# 110/110 - 23s - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.0176 - val_accuracy: 0.9966
# Epoch 95/100
# 110/110 - 24s - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.0160 - val_accuracy: 0.9977
# Epoch 96/100
# 110/110 - 23s - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0336 - val_accuracy: 0.9909
# Epoch 97/100
# 110/110 - 23s - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.0197 - val_accuracy: 0.9955
# Epoch 98/100
# 110/110 - 23s - loss: 0.0083 - accuracy: 0.9980 - val_loss: 0.0168 - val_accuracy: 0.9966
# Epoch 99/100
# 110/110 - 23s - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.0187 - val_accuracy: 0.9955
# Epoch 100/100
# 110/110 - 24s - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.0375 - val_accuracy: 0.9875

# %% [markdown]
# ## Performance do Modelo

# %%
model_NN = tf.keras.models.load_model('model_NN.h5')
model_CNN = tf.keras.models.load_model('model_CNN.h5')

# %%
def plot_accuracy_hist(model_history, fig_tittle):

    plt.rcParams.update({'font.size': 14})

    fig = plt.figure(figsize = (16, 4))
    columns = 2
    rows = 1

    fig.suptitle(fig_tittle, fontsize = 20, y = 1.08)
    fig.add_subplot(rows, columns, 1)

    plt.title('Accuracy')
    plt.ylim(0.6, 1)
    
    plt.plot(model_history.history['accuracy'], 
             color='green', 
             label = 'Train Accuracy')

    plt.plot(model_history.history['val_accuracy'], 
             color='red', 
             label = 'Test Accuracy', 
             linestyle='dashed')

    plt.legend()

    fig.add_subplot(rows, columns, 2)

    plt.title('Loss')
    plt.plot(model_history.history['loss'], 
             color='green', 
             label = 'Train Loss')

    plt.plot(model_history.history['val_loss'], 
             color='red', 
             label = 'Test Loss', 
             linestyle='dashed')

    plt.legend()

    plt.show()
    
plot_accuracy_hist(history_NN, 'Neural Network')
plot_accuracy_hist(history_CNN, 'Convolutional Neural Network')

# %% [markdown]
# ### Confusion Matrix

# %%
plt.rcParams.update({'font.size': 16})

def plot_confusion_mtx(model, x_test, plot_tittle):
    pred_prob = model.predict(x_test, batch_size = 8)
    pred = np.where(pred_prob > 0.5, 1,0)

    CM = confusion_matrix(y_test, pred)

    plot_confusion_matrix(conf_mat = CM, figsize = (16, 8))
    plt.title(plot_tittle)
    plt.xticks(range(2), labels)
    plt.yticks(range(2), labels)

    plt.show()

plot_confusion_mtx(model_NN, x_test, 'Neural Network')
plot_confusion_mtx(model_CNN, x_test, 'Convolutional Neural Network')

# %% [markdown]
# ### Receiver Operating Characteristic

# %%
pred_prob_NN  = model_NN.predict(x_test, batch_size = 8)
pred_prob_CNN = model_CNN.predict(x_test, batch_size = 8)

pred_NN  = np.where(pred_prob_NN > 0.5, 1,0)
pred_CNN = np.where(pred_prob_CNN > 0.5, 1,0)

NN_fpr, NN_tpr, _ = roc_curve(y_test, pred_prob_NN)
NN_roc_auc = auc(NN_fpr, NN_tpr)

CNN_fpr, CNN_tpr, _ = roc_curve(y_test, pred_prob_CNN)
CNN_roc_auc = auc(CNN_fpr, CNN_tpr)

plt.rcParams.update({'font.size': 16})

fig = plt.figure(figsize = (8, 6))

lw = 2
plt.plot(CNN_fpr,
         CNN_tpr, 
         color = 'darkorange',
         lw = lw, 
         label = 'CNN - ROC curve (area = %0.2f)' % CNN_roc_auc)

plt.plot(NN_fpr,
         NN_tpr, 
         color = 'grey',
         lw = lw, 
         label = '  NN - ROC curve (area = %0.2f)' % NN_roc_auc)

plt.plot([0, 1], [0, 1], 
         color = 'navy', 
         lw = lw, 
         linestyle = '--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.title('Receiver operating characteristic')
plt.legend(loc = "lower right")

plt.show()

print('Classification Report - Neural Network')
print(classification_report(y_test, pred_NN))

print('\nClassification Report - Convolutional Neural Network')
print(classification_report(y_test, pred_CNN))
# Out:
# Classification Report - Neural Network
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91       441
#            1       0.94      0.87      0.90       441
#
#     accuracy                           0.91       882
#    macro avg       0.91      0.91      0.91       882
# weighted avg       0.91      0.91      0.91       882
#
#
# Classification Report - Convolutional Neural Network
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       441
#            1       1.00      1.00      1.00       441
#
#     accuracy                           1.00       882
#    macro avg       1.00      1.00      1.00       882
# weighted avg       1.00      1.00      1.00       882
